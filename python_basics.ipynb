# %% [markdown]
# #Basics

# %% [markdown]
# 1. What is python and why is it popular?
# -< python is a interpreted programming language which is simple to use,easy to uderstand and write.
# Python is popular because-
#  .it has lot of libraries
#  .ease of learning
#  .compatible wih various programming paradigms.
#
# 2. What is an interpreter in python?
# -< Interpreter is a program that read and execute python code line by line.
#
# 3. What are predefined keywords in python?
# -< keywords are reserved words in python that have special meanings and cannot be used as identifiers
# example of keywords
# -if
# -else
# -while
# -for
# -import
# -return
#
# 4. Can keywords be used as variale names?
# -< No keywords cannot be used as variale names because keywords have special meaning.
#
# 5. What is mutability in python?
# -< Mutability is reffered to a process in which object can be modified after creation.
#
# 6. Why are list mutable and tuples immutable?
# -< Because list and tuples have different use cases and serve different     purposes in python.
# .list are used in those cases where modification is needed in the oject whereas tuples are used where no modification is needed.
#
# 7. What is difference between "==" and is operator in python?
# -< "==" checks whether 2 objects have same value or not whereas "is" checks the object identity .
#
# 8. What are logical operators in python?
# -< logical operators are used o combine and modify conditional statements .They are also known as boolean operators.
# Types of logical operators-
# . and
# . or
# . not
#
# 9. What is type casting in python?
# -< Process of changing data type of a value is known as tpe casting in python.
# types of type casting in python-
# .implicit type casting
# .explicit type casting
#
# 10. What is difference between implicit and explicit type casting?
# -<.Implicit type casting is done by python itself whereas explicit type casting is done by the programmer.
#    .There is no risk of data loss in implicit type casting whereas there is risk of data loss in explicit type casting.
#    .no special syntax is used in implicit type casting whereas casting functions are used in explicit type casting.
#
# 11. What is purpose of conditional statement in python?
# -< Purpose of condiional statement is to execute different block of codes based on different conditions.
# It is needed to control the flow of program and make program dynamic.
#
# 12. How does the elif statement work?
# -< Elif stands for else if.
# elif is used when there is need of checking multiple conditions one after another with only one block of code running.
#
# 13. What is difference between for and while loops?
# -< .For loop is used when no. of iterations are known whereas while loop is used when no. of iterations are unknown or depend on condition.
#    .FOR LOOP works with sequences whereas while loop works with boolean condition.
#    .Iteration is controlled automatically by sequences in for loop whereas in while loop iterations are conrolled manually.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop?
# -< While loop is more suitale in a scenario where user is playing a game and he/she can play untill they win.
# in this condition while loop is more suitale because here no. of attempts are unknown.

# %%
1. Write a python program to print ''Hello,world!''
print(''Hello,world!'')

2. Write a python program that displays your name and age
      name = input("ener name")
      age = int(input("enter age"))
      print ("name:",name)
      print ("age:",age)

3. Write a code to print all the predefined keywords in python using the keyword library
      keywords_list = keyword.kwlist
      print("python keywords:")
      for kw in keywords_list:
      print(kw)

4. Write a program that check if a given word is a python keyword
      x=for
      if keyword.iskeyword(x):
        print(f"'{x}'is a python keyword.")
        else:
      print(f"'{x}'is not a python keyword.")

5. create a list and tuple in python and demonstrate how attempting to change an element works differently for each
      list
      my_list = [1, 2, 3, 4, 5]
      print("list:",my list)

      tuple
      my_tuple = (1, 2, 3, 4, 5)
      print("tuple:"my tuple)

6. Write a function to demonstrate behaviour of mutable and immutable arguments

8. Write a program to demonstrate the use of logical operators
      and operator
      is_married = true
      has_one_child = true
      if is_married and has_one_child:
      prin("you are eligible for pass")
      else
      print("you are not eligible for pass")

      or operator
      cash = true
      card = false
      if cash or card:
      print("you can buy")
      else
      print("you cannot buy")

      not operator
      is_sunny = false
      if not is_sunny:
      print("it is not sunny so you should stay at home")
      else
      print("it is sunny you can go outside")

9. Write a python program to convert user input from string to integer,float and boolean types
      user_input = input("enter a value: ")

      convert to integer

      int_value = int(user_input)
      print("integer value:" , int_value)

      convert to float

      float_value = float(user_input)
      print("float value:", float_value)

      convert to boolean

      bool_value = bool(user_input)
      print("boolean value:", bool_value)

10. Write a code to demonstrate type casting with list elements
      original_list = [1,2,3.5,4,hello]

      conver to float

      float_list = [float(item) for item in original list]

      convert to strings

      string_list = [str(item) for item in original list]

      print(f"original list: {original_list}")
      print(f"list after converting to float: {float_list}")
      print(f"list after converting to srings: {strings_list}")

11. Write a program that check if a number is positive negative or zero
      number = float(input("enter a number"))

      if number > 0:
      print(f"the number is positive")
      elif number < 0:
      print(f"the number is negative")
      else
      print(f"the number is zero")

12. Write a for loop to print number from one to ten
      for i in range (1, 11):
        print (i)

13. Write a python program to find the sum of all even number between one and fifty
      for num in range (1,51):
        if num%2 ==0
      total+ = num
      print("sum of even numbers between 1 and 50 is:")

14. Write a program to reverse a string using a while loop

15.  Write a python program to calculate factorial of a number provided by user using a while loop
